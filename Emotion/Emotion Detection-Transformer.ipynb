# %%
import text2emotion as te
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/pratikaher/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/pratikaher/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/pratikaher/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
import string
import re

# %%
with open('sample.txt',  encoding='utf-8') as f:
    lines = f.read().replace('\n',' ').replace('\u2005', ' ').replace('\u205f', ' ')

# %%
lines = lines.split(' ')

# %%
result = []

for word in lines:
    if word not in string.punctuation and len(word) > 2:
        result.append(word.lower())

# %%
result
# Out:
# ['might',
#  'seem',
#  'crazy',
#  'what',
#  "'bout",
#  'say',
#  'sunshine',
#  "she's",
#  'here,',
#  'you',
#  'can',
#  'take',
#  'break',
#  "i'm",
#  'hot',
#  'air',
#  'balloon',
#  'that',
#  'could',
#  'space',
#  'with',
#  'the',
#  'air,',
#  'like',
#  "don't",
#  'care,',
#  'baby',
#  'the',
#  'way',
#  'huh',
#  '(because',
#  "i'm",
#  'happy)',
#  'clap',
#  'along',
#  'you',
#  'feel',
#  'like',
#  'room',
#  'without',
#  'roof',
#  '(because',
#  "i'm",
#  'happy)',
#  'clap',
#  'along',
#  'you',
#  'feel',
#  'like',
#  'happiness',
#  'the',
#  'truth',
#  '(because',
#  "i'm",
#  'happy)',
#  'clap',
#  'along',
#  'you',
#  'know',
#  'what',
#  'happiness',
#  'you',
#  '(because',
#  "i'm",
#  'happy)',
#  'clap',
#  'along',
#  'you',
#  'feel',
#  'like',
#  "that's",
#  'what',
#  'you',
#  'wanna',
#  'here',
#  'come',
#  'bad',
#  'news',
#  'talking',
#  'this',
#  'and',
#  'that',
#  '(yeah)',
#  'well',
#  'give',
#  'all',
#  'you',
#  'got,',
#  "don't",
#  'hold',
#  'back',
#  '(yeah)',
#  'well',
#  'should',
#  'probably',
#  'warn',
#  'you',
#  "i'll",
#  'just',
#  'fine',
#  '(yeah)',
#  'offence',
#  'you',
#  "don't",
#  'waste',
#  'your',
#  'time',
#  "here's",
#  'why',
#  'clap',
#  'along',
#  'you',
#  'feel',
#  'like',
#  'room',
#  'without',
#  'roof',
#  '(because',
#  "i'm",
#  'happy)',
#  'clap',
#  'along',
#  'you',
#  'feel',
#  'like',
#  'happiness',
#  'the',
#  'truth',
#  '(because',
#  "i'm",
#  'happy)',
#  'clap',
#  'along',
#  'you',
#  'know',
#  'what',
#  'happiness',
#  'you',
#  '(because',
#  "i'm",
#  'happy)',
#  'clap',
#  'along',
#  'you',
#  'feel',
#  'like',
#  "that's",
#  'what',
#  'you',
#  'wanna',
#  'uh,',
#  'bring',
#  'down',
#  "can't",
#  'nothing,',
#  'bring',
#  'down',
#  "level's",
#  'too',
#  'high',
#  'bring',
#  'down',
#  "can't",
#  'nothing,',
#  'bring',
#  'down,',
#  'said',
#  'bring',
#  'down,',
#  "can't",
#  'nothing',
#  'bring',
#  'down',
#  "level's",
#  'too',
#  'high',
#  'bring',
#  'down',
#  "can't",
#  'nothing,',
#  'bring',
#  'down,',
#  'said',
#  'clap',
#  'along',
#  'you',
#  'feel',
#  'like',
#  'room',
#  'without',
#  'roof',
#  '(because',
#  "i'm",
#  'happy)',
#  'clap',
#  'along',
#  'you',
#  'feel',
#  'like',
#  'happiness',
#  'the',
#  'truth',
#  '(because',
#  "i'm",
#  'happy)',
#  'clap',
#  'along',
#  'you',
#  'know',
#  'what',
#  'happiness',
#  'you',
#  '(because',
#  "i'm",
#  'happy)',
#  'clap',
#  'along',
#  'you',
#  'feel',
#  'like',
#  "that's",
#  'what',
#  'you',
#  'wanna',
#  'clap',
#  'along',
#  'you',
#  'feel',
#  'like',
#  'room',
#  'without',
#  'roof',
#  '(because',
#  "i'm",
#  'happy)',
#  'clap',
#  'along',
#  'you',
#  'feel',
#  'like',
#  'happiness',
#  'the',
#  'truth',
#  '(because',
#  "i'm",
#  'happy)',
#  'clap',
#  'along',
#  'you',
#  'know',
#  'what',
#  'happiness',
#  'you',
#  '(because',
#  "i'm",
#  'happy)',
#  'clap',
#  'along',
#  'you',
#  'feel',
#  'like',
#  "that's",
#  'what',
#  'you',
#  'wanna',
#  'uh,',
#  'bring',
#  'down',
#  '(happy,',
#  'happy,',
#  'happy,',
#  'happy)',
#  "can't",
#  'nothing',
#  '(happy,',
#  'happy,',
#  'happy,',
#  'happy)',
#  'bring',
#  'down,',
#  "level's",
#  'too',
#  'high',
#  'bring',
#  'down',
#  '(happy,',
#  'happy,',
#  'happy,',
#  'happy)',
#  "can't",
#  'nothing',
#  '(happy,',
#  'happy,',
#  'happy,',
#  'happy)',
#  'bring',
#  'down,',
#  'said',
#  'clap',
#  'along',
#  'you',
#  'feel',
#  'like',
#  'room',
#  'without',
#  'roof',
#  '(because',
#  "i'm",
#  'happy)',
#  'clap',
#  'along',
#  'you',
#  'feel',
#  'like',
#  'happiness',
#  'the',
#  'truth',
#  '(because',
#  "i'm",
#  'happy)',
#  'clap',
#  'along',
#  'you',
#  'know',
#  'what',
#  'happiness',
#  'you',
#  '(ayy,',
#  'ayy,',
#  'ayy)',
#  '(because',
#  "i'm",
#  'happy)',
#  'clap',
#  'along',
#  'you',
#  'feel',
#  'like',
#  "that's",
#  'what',
#  'you',
#  'wanna',
#  'clap',
#  'along',
#  'you',
#  'feel',
#  'like',
#  'room',
#  'without',
#  'roof',
#  '(because',
#  "i'm",
#  'happy)',
#  'clap',
#  'along',
#  'you',
#  'feel',
#  'like',
#  'happiness',
#  'the',
#  'truth',
#  '(because',
#  "i'm",
#  'happy)',
#  'clap',
#  'along',
#  'you',
#  'know',
#  'what',
#  'happiness',
#  'you',
#  '(hey)',
#  '(because',
#  "i'm",
#  'happy)',
#  'clap',
#  'along',
#  'you',
#  'feel',
#  'like',
#  "that's",
#  'what',
#  'you',
#  'wanna',
#  'come']

# %%
len(lines)
# Out:
# 482

# %%
final_result = {'Happy': 0, 'Angry': 0, 'Surprise': 0, 'Sad': 0, 'Fear': 0}

# %%
count = 0

for i in range(0,len(lines), 20):
    
    count += 1
    intermediate = ' '.join(lines[i:i+20])
    
    emotion = te.get_emotion(intermediate)
    
    print(intermediate, emotion)
    
    for key, value in emotion.items():
        
        final_result[key] += value
    
#     print(intermediate, te.get_emotion(intermediate))
# Out:
# It might seem crazy what I am 'bout to say Sunshine she's here, you can take a break I'm a {'Happy': 0.0, 'Angry': 0.2, 'Surprise': 0.4, 'Sad': 0.2, 'Fear': 0.2}
# hot air balloon that could go to space With the air, like I don't care, baby by the way Huh {'Happy': 0.0, 'Angry': 0.33, 'Surprise': 0.33, 'Sad': 0.33, 'Fear': 0.0}
# (Because I'm happy) Clap along if you feel like a room without a roof (Because I'm happy) Clap along if {'Happy': 0.33, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.33, 'Fear': 0.33}
# you feel like happiness is the truth (Because I'm happy) Clap along if you know what happiness is to you {'Happy': 0.75, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.25, 'Fear': 0.0}
# (Because I'm happy) Clap along if you feel like that's what you wanna do Here come bad news talking this {'Happy': 0.25, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.75, 'Fear': 0.0}
# and that (Yeah) Well give me all you got, don't hold back (Yeah) Well I should probably warn you I'll {'Happy': 0.0, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.0, 'Fear': 1.0}
# be just fine (Yeah) No offence to you don't waste your time Here's why Clap along if you feel like {'Happy': 0.5, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.5, 'Fear': 0.0}
# a room without a roof (Because I'm happy) Clap along if you feel like happiness is the truth (Because I'm {'Happy': 0.4, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.2, 'Fear': 0.4}
# happy) Clap along if you know what happiness is to you (Because I'm happy) Clap along if you feel like {'Happy': 0.6, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.4, 'Fear': 0.0}
# that's what you wanna do Uh, bring me down Can't nothing, bring me down My level's too high to bring {'Happy': 0.0, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.8, 'Fear': 0.2}
# me down Can't nothing, bring me down, I said Bring me down, can't nothing Bring me down My level's too {'Happy': 0.0, 'Angry': 0.0, 'Surprise': 0.25, 'Sad': 0.75, 'Fear': 0.0}
# high to bring me down Can't nothing, bring me down, I said Clap along if you feel like a room {'Happy': 0.0, 'Angry': 0.0, 'Surprise': 0.17, 'Sad': 0.5, 'Fear': 0.33}
# without a roof (Because I'm happy) Clap along if you feel like happiness is the truth (Because I'm happy) Clap {'Happy': 0.5, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.33, 'Fear': 0.17}
# along if you know what happiness is to you (Because I'm happy) Clap along if you feel like that's what {'Happy': 0.67, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.33, 'Fear': 0.0}
# you wanna do Clap along if you feel like a room without a roof (Because I'm happy) Clap along if {'Happy': 0.17, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.5, 'Fear': 0.33}
# you feel like happiness is the truth (Because I'm happy) Clap along if you know what happiness is to you {'Happy': 0.75, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.25, 'Fear': 0.0}
# (Because I'm happy) Clap along if you feel like that's what you wanna do Uh, bring me down (Happy, happy, {'Happy': 0.5, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.5, 'Fear': 0.0}
# happy, happy) Can't nothing (Happy, happy, happy, happy) Bring me down, my level's too high To bring me down (Happy, {'Happy': 0.7, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.2, 'Fear': 0.1}
# happy, happy, happy) Can't nothing (Happy, happy, happy, happy) Bring me down, I said Clap along if you feel like {'Happy': 0.7, 'Angry': 0.0, 'Surprise': 0.1, 'Sad': 0.2, 'Fear': 0.0}
# a room without a roof (Because I'm happy) Clap along if you feel like happiness is the truth (Because I'm {'Happy': 0.4, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.2, 'Fear': 0.4}
# happy) Clap along if you know what happiness is to you (ayy, ayy, ayy) (Because I'm happy) Clap along if {'Happy': 0.6, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.4, 'Fear': 0.0}
# you feel like that's what you wanna do Clap along if you feel like a room without a roof (Because {'Happy': 0.0, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.5, 'Fear': 0.5}
# I'm happy) Clap along if you feel like happiness is the truth (Because I'm happy) Clap along if you know {'Happy': 0.6, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.4, 'Fear': 0.0}
# what happiness is to you (hey) (Because I'm happy) Clap along if you feel like that's what you wanna do {'Happy': 0.4, 'Angry': 0.0, 'Surprise': 0.2, 'Sad': 0.4, 'Fear': 0.0}
# Come on {'Happy': 0, 'Angry': 0, 'Surprise': 0, 'Sad': 0, 'Fear': 0}

# %%
final_result
# Out:
# {'Happy': 9.212075298438936,
#  'Angry': 0.5540955004591368,
#  'Surprise': 1.50831955922865,
#  'Sad': 9.59077134986226,
#  'Fear': 4.113820018365473}

# %%
count
# Out:
# 25

# %%
for key in final_result:
    final_result[key] /= count

# %%
final_result
# Out:
# {'Happy': 0.36848301193755745,
#  'Angry': 0.022163820018365473,
#  'Surprise': 0.060332782369146,
#  'Sad': 0.38363085399449043,
#  'Fear': 0.16455280073461892}

# %%
# !pip3 install transformers
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Collecting transformers
#   Downloading transformers-4.12.5-py3-none-any.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 9.5 MB/s
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.1.2-py3-none-any.whl (59 kB)
#      |████████████████████████████████| 59 kB 21.9 MB/s
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp39-cp39-macosx_11_0_arm64.whl (173 kB)
#      |████████████████████████████████| 173 kB 53.2 MB/s
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.3.tar.gz (212 kB)
#      |████████████████████████████████| 212 kB 44.1 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting filelock
#   Downloading filelock-3.4.0-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: numpy>=1.17 in /opt/homebrew/lib/python3.9/site-packages (from transformers) (1.21.4)
# Requirement already satisfied: tqdm>=4.27 in /opt/homebrew/lib/python3.9/site-packages (from transformers) (4.62.3)
# Collecting requests
#   Using cached requests-2.26.0-py2.py3-none-any.whl (62 kB)
# Collecting sacremoses
#   Downloading sacremoses-0.0.46-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 72.7 MB/s
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/lib/python3.9/site-packages (from transformers) (21.3)
# Requirement already satisfied: regex!=2019.12.17 in /opt/homebrew/lib/python3.9/site-packages (from transformers) (2021.11.10)
# Collecting typing-extensions>=3.7.4.3
#   Using cached typing_extensions-4.0.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/homebrew/lib/python3.9/site-packages (from packaging>=20.0->transformers) (3.0.6)
# Collecting idna<4,>=2.5
#   Using cached idna-3.3-py3-none-any.whl (61 kB)
# Collecting certifi>=2017.4.17
#   Using cached certifi-2021.10.8-py2.py3-none-any.whl (149 kB)
# Collecting urllib3<1.27,>=1.21.1
#   Using cached urllib3-1.26.7-py2.py3-none-any.whl (138 kB)
# Collecting charset-normalizer~=2.0.0
#   Downloading charset_normalizer-2.0.8-py3-none-any.whl (39 kB)
# Requirement already satisfied: joblib in /opt/homebrew/lib/python3.9/site-packages (from sacremoses->transformers) (1.1.0)
# Requirement already satisfied: click in /opt/homebrew/lib/python3.9/site-packages (from sacremoses->transformers) (8.0.3)
# Requirement already satisfied: six in /opt/homebrew/lib/python3.9/site-packages (from sacremoses->transformers) (1.16.0)
# Building wheels for collected packages: tokenizers
#   Building wheel for tokenizers (pyproject.toml) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /opt/homebrew/opt/python@3.9/bin/python3.9 /opt/homebrew/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py build_wheel /var/folders/7w/pm43w7t11438_6102vq5jc6c0000gn/T/tmpnegnt5g_
#        cwd: /private/var/folders/7w/pm43w7t11438_6102vq5jc6c0000gn/T/pip-install-g8_oe8c6/tokenizers_528d10399fa5492f9156674917d7d889
#   Complete output (51 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib.macosx-11-arm64-3.9
#   creating build/lib.macosx-11-arm64-3.9/tokenizers
#   copying py_src/tokenizers/__init__.py -> build/lib.macosx-11-arm64-3.9/tokenizers
#   creating build/lib.macosx-11-arm64-3.9/tokenizers/models
#   copying py_src/tokenizers/models/__init__.py -> build/lib.macosx-11-arm64-3.9/tokenizers/models
#   creating build/lib.macosx-11-arm64-3.9/tokenizers/decoders
#   copying py_src/tokenizers/decoders/__init__.py -> build/lib.macosx-11-arm64-3.9/tokenizers/decoders
#   creating build/lib.macosx-11-arm64-3.9/tokenizers/normalizers
#   copying py_src/tokenizers/normalizers/__init__.py -> build/lib.macosx-11-arm64-3.9/tokenizers/normalizers
#   creating build/lib.macosx-11-arm64-3.9/tokenizers/pre_tokenizers
#   copying py_src/tokenizers/pre_tokenizers/__init__.py -> build/lib.macosx-11-arm64-3.9/tokenizers/pre_tokenizers
#   creating build/lib.macosx-11-arm64-3.9/tokenizers/processors
#   copying py_src/tokenizers/processors/__init__.py -> build/lib.macosx-11-arm64-3.9/tokenizers/processors
#   creating build/lib.macosx-11-arm64-3.9/tokenizers/trainers
#   copying py_src/tokenizers/trainers/__init__.py -> build/lib.macosx-11-arm64-3.9/tokenizers/trainers
#   creating build/lib.macosx-11-arm64-3.9/tokenizers/implementations
#   copying py_src/tokenizers/implementations/byte_level_bpe.py -> build/lib.macosx-11-arm64-3.9/tokenizers/implementations
#   copying py_src/tokenizers/implementations/sentencepiece_unigram.py -> build/lib.macosx-11-arm64-3.9/tokenizers/implementations
#   copying py_src/tokenizers/implementations/sentencepiece_bpe.py -> build/lib.macosx-11-arm64-3.9/tokenizers/implementations
#   copying py_src/tokenizers/implementations/base_tokenizer.py -> build/lib.macosx-11-arm64-3.9/tokenizers/implementations
#   copying py_src/tokenizers/implementations/__init__.py -> build/lib.macosx-11-arm64-3.9/tokenizers/implementations
#   copying py_src/tokenizers/implementations/char_level_bpe.py -> build/lib.macosx-11-arm64-3.9/tokenizers/implementations
#   copying py_src/tokenizers/implementations/bert_wordpiece.py -> build/lib.macosx-11-arm64-3.9/tokenizers/implementations
#   creating build/lib.macosx-11-arm64-3.9/tokenizers/tools
#   copying py_src/tokenizers/tools/__init__.py -> build/lib.macosx-11-arm64-3.9/tokenizers/tools
#   copying py_src/tokenizers/tools/visualizer.py -> build/lib.macosx-11-arm64-3.9/tokenizers/tools
#   copying py_src/tokenizers/__init__.pyi -> build/lib.macosx-11-arm64-3.9/tokenizers
#   copying py_src/tokenizers/models/__init__.pyi -> build/lib.macosx-11-arm64-3.9/tokenizers/models
#   copying py_src/tokenizers/decoders/__init__.pyi -> build/lib.macosx-11-arm64-3.9/tokenizers/decoders
#   copying py_src/tokenizers/normalizers/__init__.pyi -> build/lib.macosx-11-arm64-3.9/tokenizers/normalizers
#   copying py_src/tokenizers/pre_tokenizers/__init__.pyi -> build/lib.macosx-11-arm64-3.9/tokenizers/pre_tokenizers
#   copying py_src/tokenizers/processors/__init__.pyi -> build/lib.macosx-11-arm64-3.9/tokenizers/processors
#   copying py_src/tokenizers/trainers/__init__.pyi -> build/lib.macosx-11-arm64-3.9/tokenizers/trainers
#   copying py_src/tokenizers/tools/visualizer-styles.css -> build/lib.macosx-11-arm64-3.9/tokenizers/tools
#   running build_ext
#   running build_rust
#   error: can't find Rust compiler
#
#   If you are using an outdated pip version, it is possible a prebuilt wheel is available for this package but pip is not able to install from it. Installing from the wheel would avoid the need for a Rust compiler.
#
#   To update pip, run:
#
#       pip install --upgrade pip
#
#   and then retry package installation.
#
#   If you did intend to build this package from source, try installing a Rust compiler from your system package manager and ensure it is on the PATH during installation. Alternatively, rustup (available at https://rustup.rs) is the recommended way to download and update the Rust compiler toolchain.
#   ----------------------------------------
#   ERROR: Failed building wheel for tokenizers
# Failed to build tokenizers
# ERROR: Could not build wheels for tokenizers, which is required to install pyproject.toml-based projects

# %%
from transformers import pipeline
classifier = pipeline("text-classification",model='bhadresh-savani/distilbert-base-uncased-emotion', return_all_scores=True)
prediction = classifier("I love using transformers. The best part is wide range of support and its easy to use", )
print(prediction)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/7w/pm43w7t11438_6102vq5jc6c0000gn/T/ipykernel_39269/2834353476.py in <module>
# ----> 1 from transformers import pipeline
#       2 classifier = pipeline("text-classification",model='bhadresh-savani/distilbert-base-uncased-emotion', return_all_scores=True)
#       3 prediction = classifier("I love using transformers. The best part is wide range of support and its easy to use", )
#       4 print(prediction)
#
# ModuleNotFoundError: No module named 'transformers'
