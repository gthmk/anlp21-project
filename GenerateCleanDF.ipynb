# %%
#general packages
import os
import string
import copy
import json
import pickle
from ast import literal_eval
import operator

#dataframe and data science packages
import pandas as pd
import numpy as np
import re

#nltk packages
import nltk
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer 
from nltk.corpus import stopwords

#gensim packages
import gensim
from gensim import corpora
from gensim.corpora.dictionary import Dictionary
from gensim.models import CoherenceModel

#emotion detection packages
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import text2emotion as te
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/romitbarua/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/romitbarua/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/romitbarua/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# %run CleanLyricsAndTabsAndKeys.ipynb
# %run FeatureReduction.ipynb
# %run EmotionGenerator.ipynb

# %% [markdown]
# # Import and Combine the Data
# 1. Import the files
#     a. Spotify Data
#     b. Dirty Tab Data
#     c. Dirty Song Data

# %% [markdown]
# ## Import the Spotify & Tab Files

# %%
spotify_df = pd.read_csv('playlist_tracks.csv')
tab_df = pd.read_csv('track_with_tabs_new.csv')

# %% [markdown]
# ## Add the Tab Data to the Spotify Data

# %%
#make sure both the spotify and tab df have the same index & join
spotify_df = spotify_df.set_index('track_id')
spotify_df = spotify_df[~spotify_df.index.duplicated(keep='first')]

tab_df = tab_df.set_index('track_id')
tab_df = tab_df[~tab_df.index.duplicated(keep='first')]

df = pd.concat([spotify_df, tab_df], join='inner', axis=1)
df = df.rename(columns={'tabs':'dirty_tabs'})
df = df.reset_index()
print(df.shape)
# Out:
# (13530, 18)

# %% [markdown]
# ## Add the Dirty Lyrics to the DF

# %%
import os
lyrics_path = 'lyrics_text/'
for filename in os.listdir(lyrics_path):
    filename.replace('output2','')
    try:
        if '.txt' in filename:
            file = open('lyrics_text/'+filename)
            song_id = filename.replace('.txt','')
            df.loc[df.track_id == song_id, 'dirty_lyrics'] = file.read()
    except:
        print('Failed to Upload: {}'.format(filename))
        pass
#remove the cases where we have no lyrics
df = df.dropna()
print(df.shape)
# Out:
# (8008, 19)

# %% [markdown]
# ## Clean the Dirty Lyrics & Generate Words for LDA

# %%
print('Cleaning Lyrics -> ', end='')
#functions come from CleanLyricsAndTabsAndKeys.ipynb
df = removeLongSongs(df, 92)
#df.shape
df['clean_lyrics'] = df['dirty_lyrics'].apply(lambda x: clean_lyrics(str(x)))
df['words_for_LDA'] = df['clean_lyrics'].apply(lambda x: lyrics_to_words(str(x)))

print('Lyrics Cleaned')
print(df.shape)
# Out:
# Cleaning Lyrics -> Lyrics Cleaned
# (7367, 21)

# %% [markdown]
# ## Clean the Dirty Tabs

# %%
print('Cleaning Tab -> ', end='')

df['clean_tabs'] = df['dirty_tabs'].apply(lambda x: convertToSharp(x))
df['clean_tabs'] = df.apply(lambda x: moveForCapo(x['clean_tabs'], x['capo']), axis=1)

print('Tab Cleaned')
# Out:
# Cleaning Tab -> Tab Cleaned

# %%
df = df.reset_index()

# %% [markdown]
# ## Get the Greer, First Chord Keys and Last Chord Keys

# %%
df = df.rename(columns={'key': 'spotify_key'})

# %%
print('Building Key Data -> ', end='')

df['greer_key'] = df['clean_tabs'].apply(lambda x: findTonicNumNo7(x.split(',')))
df['firstNote_key'] = df['clean_tabs'].apply(lambda x: ChordToNum(sepExt(x.split(',')[0])[0]))
df['lastNote_key'] = df['clean_tabs'].apply(lambda x: ChordToNum(sepExt(x.split(',')[-1])[0]))
df['bestChoice_key'] = df.apply(lambda x: pickMainKey(x), axis=1)

print('Key Data Built')
# Out:
# Building Key Data -> Key Data Built

# %%
df
# Out:
#       index                track_id                    playlist_name  \
# 0         0  3YBZIN3rekqsKxbJc9FZko                    Rock Classics
# 1         1  2zYzyRzz6pRmhPzyfMEC8s                    Rock Classics
# 2         2  5MxNLUsfh7uzROypsoO5qe                    Rock Classics
# 3         3  70LcF31zb1H0PyJoS1Sx1r                    Rock Classics
# 4         4  4bHsxqR3GMrXTxEPLuK5ue                    Rock Classics
# ...     ...                     ...                              ...
# 7362  12607  5xLfQuX5YAfog2JgPz0dpA  Sirius XM Top 1000 Classic Rock
# 7363  12608  4i6wwcBc3Qrqir83xBdbM6  Sirius XM Top 1000 Classic Rock
# 7364  12609  6oO4MqRSMxIDFqX1OQnVAz  Sirius XM Top 1000 Classic Rock
# 7365  13492  5J4ZkQpzMUFojo1CtAZYpn                  Top 10000 songs
# 7366  13513  74irxdVWstNlEQjsvArITq                  Top 10000 songs
#
#                  playlist_id playlist_genre  \
# 0     37i9dQZF1DWXRqgorJj26U           Rock
# 1     37i9dQZF1DWXRqgorJj26U           Rock
# 2     37i9dQZF1DWXRqgorJj26U           Rock
# 3     37i9dQZF1DWXRqgorJj26U           Rock
# 4     37i9dQZF1DWXRqgorJj26U           Rock
# ...                      ...            ...
# 7362  7eDSv2WJi5Loto9fIwvthi           MIsc
# 7363  7eDSv2WJi5Loto9fIwvthi           MIsc
# 7364  7eDSv2WJi5Loto9fIwvthi           MIsc
# 7365  04SNbStKKx0pM8CF63RHgX           Misc
# 7366  04SNbStKKx0pM8CF63RHgX           Misc
#
#                                    track_name track_artist_name  \
# 0                               Paradise City     Guns N' Roses
# 1                             Highway to Hell             AC/DC
# 2                                    Dream On         Aerosmith
# 3                                       Creep         Radiohead
# 4                        Don't Stop Believin'           Journey
# ...                                       ...               ...
# 7362                         Moving in Stereo          The Cars
# 7363  Saturday Night's Alright (For Fighting)        Elton John
# 7364                                Boulevard    Jackson Browne
# 7365                           Love Me Harder     Ariana Grande
# 7366                                    Crazy         Aerosmith
#
#              track_artist_id  danceability  energy  ...  \
# 0     3qm84nBOXUEQ2vnTfUTTFC         0.273   0.952  ...
# 1     711MCceyCBcFnzjGY4Q7Un         0.574   0.913  ...
# 2     7Ey4PD4MYsKc5I2dolUwbH         0.307   0.433  ...
# 3     4Z8W4fKeB5YxbusRsdQVPb         0.515   0.430  ...
# 4     0rvjqX7ttXeg3mTy8Xscbt         0.500   0.748  ...
# ...                      ...           ...     ...  ...
# 7362  6DCIj8jNaNpBz8e5oKFPtp         0.718   0.543  ...
# 7363  3PhoLpVuITZKcymswpck5b         0.490   0.984  ...
# 7364  5lkiCO9UQ8B23dZ1o0UV4m         0.541   0.855  ...
# 7365  66CXWjxzNUsdJxJ2JdwvnR         0.472   0.714  ...
# 7366  7Ey4PD4MYsKc5I2dolUwbH         0.370   0.866  ...
#
#                                              dirty_tabs  capo  \
# 0     G,C,F,C,G,G5,F5,C5,Bb5,C5,C5,Bb5,G,F,G,G,G,C,C...     0
# 1     A,D/F#,G,D/F#,G,D/F#,G,D/F#,A,A,A,A,D/F#,D/F#,...     0
# 2     Fm,Cm/F,Fm6,Bbm6,Fm,C7sus,Fm,Fm,Fm7,Fm6,Bbm6,F...     0
# 3     G,B,C,Cm,G,B,C,Cm,G,B,C,Cm,G,B,C,Cm,G,B,C,Cm,G...     0
# 4     E,B,C#m,A,E,B,G#m,A,E,B,C#m,A,E,B,G#m,A,E,B,C#...     0
# ...                                                 ...   ...
# 7362                E,D,D,F#,E,E,D,D,E,E,D,D,F#,E,E,D,C     0
# 7363  G/D,F/C,G,F/G,G,F/G,G/D,F/C,G,F/G,G,F/G,G,F,C,...     0
# 7364  Am,Dm,F,E,Am,Am,Dm,F,E,Am,Am,Dm,F,E,Am,Am,Dm,G...     0
# 7365  F,Am,Dm,Em,F,Am,Dm,Em,G,F,Am,Dm,Em,G,F,Am,Dm,E...     4
# 7366  Cm,Cm,Eb,Ab,Gsus4,G,Cm,Eb,Ab,Gsus4,G,Cm,Eb,Ab,...     0
#
#                                            dirty_lyrics  \
# 0     [Chorus]\nTake me down to the Paradise City\nW...
# 1     [Instrumental Intro]\n\n[Verse 1]\nLiving easy...
# 2     [Verse 1]\nEvery time​ that I look in the mirr...
# 3     [Verse 1]\nWhen you were here before\nCouldn't...
# 4     [Verse 1]\nJust a small-town girl\nLivin' in a...
# ...                                                 ...
# 7362  [Verse 1]\nLife's the same, I'm moving in ster...
# 7363  [Verse 1]\nIt's getting late, have you seen my...
# 7364  [Verse 1]\nDown on the boulevard they take it ...
# 7365  [Verse 1: Ariana Grande]\nTell me something I ...
# 7366  [Intro: Steven Tyler]\nCome here, baby\nYou kn...
#
#                                            clean_lyrics  \
# 0     \nTake me down to the Paradise City\nWhere the...
# 1     \n\n\nLiving easy, lovin' free\nSeason ticket ...
# 2     \nEvery time​ that I look in the mirror\nAll t...
# 3     \nWhen you were here before\nCouldn't look you...
# 4     \nJust a small-town girl\nLivin' in a lonely w...
# ...                                                 ...
# 7362  \nLife's the same, I'm moving in stereo\nLife'...
# 7363  \nIt's getting late, have you seen my mates?\n...
# 7364  \nDown on the boulevard they take it hard\nThe...
# 7365  \nTell me something I need to know\nThen take ...
# 7366  \nCome here, baby\nYou know you drive me up a ...
#
#                                           words_for_LDA  \
# 0     [take, paradise, city, grass, green, girl, pre...
# 1     [living, easy, lovin, free, ticket, ride, aski...
# 2     [time, look, mirror, line, face, getting, clea...
# 3     [look, eye, skin, cry, float, feather, beautif...
# 4     [small, town, girl, livin, lonely, world, took...
# ...                                                 ...
# 7362  [life, moving, stereo, life, shoe, life, shaki...
# 7363  [getting, late, seen, mate, boy, clock, wanna,...
# 7364  [boulevard, take, hard, look, life, disregard,...
# 7365  [need, take, breath, invade, space, take, plea...
# 7366  [baby, drive, wall, nasty, trick, pull, makin,...
#
#                                              clean_tabs greer_key  \
# 0     G,C,F,C,G,G5,F5,C5,A#5,C5,C5,A#5,G,F,G,G,G,C,C...         0
# 1     A,D/F#,G,D/F#,G,D/F#,G,D/F#,A,A,A,A,D/F#,D/F#,...         2
# 2     Fm,Cm/F,Fm6,A#m6,Fm,C7sus,Fm,Fm,Fm7,Fm6,A#m6,F...         8
# 3     G,B,C,Cm,G,B,C,Cm,G,B,C,Cm,G,B,C,Cm,G,B,C,Cm,G...         0
# 4     E,B,C#m,A,E,B,G#m,A,E,B,C#m,A,E,B,G#m,A,E,B,C#...         4
# ...                                                 ...       ...
# 7362                E,D,D,F#,E,E,D,D,E,E,D,D,F#,E,E,D,C         9
# 7363  G/D,F/C,G,F/G,G,F/G,G/D,F/C,G,F/G,G,F/G,G,F,C,...         0
# 7364  Am,Dm,F,E,Am,Am,Dm,F,E,Am,Am,Dm,F,E,Am,Am,Dm,G...         0
# 7365  A,C#m,F#m,G#m,A,C#m,F#m,G#m,B,A,C#m,F#m,G#m,B,...         4
# 7366  Cm,Cm,D#,G#,Gsus4,G,Cm,D#,G#,Gsus4,G,Cm,D#,G#,...         3
#
#      firstNote_key  lastNote_key bestChoice_key
# 0                7             7              7
# 1                9             9              9
# 2                5             0              8
# 3                7             7              7
# 4                4             9              4
# ...            ...           ...            ...
# 7362             4             0              4
# 7363             2             0              0
# 7364             9             9              9
# 7365             9             9              9
# 7366             0             0              0
#
# [7367 rows x 27 columns]

# %% [markdown]
# # Extract the Emotions from the Song

# %% [markdown]
# ## Use the Text2Emotion Package

# %%
print('Extracting Emotions -> ', end='')

df['text2emotion'] = df['words_for_LDA'].apply(lambda x: buildText2EmotionJson(str(x)))
df['vader_emotion'] = df['words_for_LDA'].apply(lambda x: buildVaderEmotionJson(str(x)))

print('Emotions Extracted')
# Out:
# Extracting Emotions -> Emotions Extracted

# %% [markdown]
# # Save Down the Cleaned DF

# %%
#df.to_csv('Clean_DF.csv', index=False)
import pickle

pickle_out = open("Clean_DF.pickle","wb")
pickle.dump(df, pickle_out)
pickle_out.close()
